# %% [markdown]
# <h4>Notebook is created to show how to hide cells from publishing in Github or when shared.</h4>
# <h5>Author: Charles Gomes - https://github.com/charles2588

# %%
#Visible cell
print("Hello world of Data!!!")
# Out:
# Hello world of Data!!!

# %%
#@hidden_cell
connection_string = "jdbc://abchost.com/mydatabase?username=name&password=xyz123"

# %%
import os, types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.

if os.environ.get('RUNTIME_ENV_LOCATION_TYPE') == 'external':
    endpoint_5ef842dec2ef45829b3a668c4030ed9b = 'https://s3-api.us-geo.objectstorage.softlayer.net'
else:
    endpoint_5ef842dec2ef45829b3a668c4030ed9b = 'https://s3-api.us-geo.objectstorage.service.networklayer.com'

client_5ef842dec2ef45829b3a668c4030ed9b = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='XXXXXXXXXXXXXXXX',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url=endpoint_5ef842dec2ef45829b3a668c4030ed9b)

body = client_5ef842dec2ef45829b3a668c4030ed9b.get_object(Bucket='XXXXXXXXXX',Key='15m.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

df_data_1 = pd.read_csv(body)
df_data_1.head()
# Out:
# ---------------------------------------------------------------------------
# CredentialRetrievalError                  Traceback (most recent call last)
# <ipython-input-4-8ac22bd3f8de> in <module>
#      21     endpoint_url=endpoint_5ef842dec2ef45829b3a668c4030ed9b)
#      22
# ---> 23 body = client_5ef842dec2ef45829b3a668c4030ed9b.get_object(Bucket='XXXXXXXXXX',Key='15m.csv')['Body']
#      24 # add missing __iter__ method, so pandas accepts body as file-like object
#      25 if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )
#
# /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages/ibm_botocore/client.py in _api_call(self, *args, **kwargs)
#     314                     "%s() only accepts keyword arguments." % py_operation_name)
#     315             # The "self" in this scope is referring to the BaseClient.
# --> 316             return self._make_api_call(operation_name, kwargs)
#     317
# ...
